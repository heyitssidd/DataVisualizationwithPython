# %% [markdown]
# # WATER QUALITY TESTING DATA ANALYSIS

# %% [markdown]
# Water quality is a crucial aspect of environmental management, and it is essential to measure various physical, chemical, and biological parameters to monitor it effectively. This dataset of 200 rows contains measurements of six critical water quality parameters widely used in water quality monitoring and analysis. The dataset provides a representative snapshot of water quality and can be used for various research, education, and decision-making purposes.
#
# The six parameters measured in this dataset are:
#
# pH: pH measures the acidity or basicity of a liquid on a scale from 0 to 14. Values less than 7 indicate acidic conditions, values greater than 7 suggest primary needs and a value of 7 indicates a neutral state.
#
# Dissolved Oxygen (DO): DO measures the amount of oxygen dissolved in water and is essential for aquatic life. High DO levels are crucial for the survival of fish and other marine organisms.
#
# Temperature: Temperature affects various physical, chemical, and biological processes in water bodies. It is an essential factor that influences the rate of many aquatic processes.
#
# Turbidity (NTU): Turbidity is the measure of relative clarity of a liquid. It is an optical characteristic of water and is a measurement of the amount of light that is scattered by material in the water when a light is shined through the water sample. The higher the intensity of scattered light, the higher the turbidity.
#
# Conductivity (µS/cm): Pure water is not a good conductor of electricity. Ordinary distilled water in equilibrium with carbon dioxide of the air has a conductivity of about 10 x 10-6 W-1*m-1 (20 dS/m). Because the electrical current is transported by the ions in solution, the conductivity increases as the concentration of ions increases.
#
#
# ![](data:image/jpeg;base64,...)
# ![](https://i0.wp.com/businessday.ng/wp-content/uploads/2021/10/Water-Pollution-1.png?fit=700%2C400)
#
# This dataset is taken from an opensource site [https://www.kaggle.com/](https://www.kaggle.com/)

# %%
import opendatasets as od

# %%
od.download('https://www.kaggle.com/datasets/shreyanshverma27/water-quality-testing')
# Out:
# Skipping, found downloaded files in ".\water-quality-testing" (use force=True to force download)

# %%
import os

# %%
os.listdir('water-quality-testing')
# Out:
# ['Water Quality Testing.csv']

# %%
import pandas as pd

# %%
water_quality_df = pd.read_csv('water-quality-testing/Water Quality Testing.csv')
water_quality_df
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 0            1  7.25              23.1              4.5
# 1            2  7.11              22.3              5.1
# 2            3  7.03              21.5              3.9
# 3            4  7.38              22.9              3.2
# 4            5  7.45              20.7              3.8
# ..         ...   ...               ...              ...
# 495        496  7.01              20.8              4.6
# 496        497  7.31              22.5              3.8
# 497        498  7.02              21.2              4.7
# 498        499  7.25              23.0              3.9
# 499        500  7.12              20.9              4.4
#
#      Dissolved Oxygen (mg/L)  Conductivity (µS/cm)
# 0                        7.8                   342
# 1                        6.2                   335
# 2                        8.3                   356
# 3                        9.5                   327
# ...

# %% [markdown]
# Lets see all the columns mentioned in the data frame...

# %%
water_quality_df.columns
# Out:
# Index(['Sample ID', 'pH', 'Temperature (°C)', 'Turbidity (NTU)',
#        'Dissolved Oxygen (mg/L)', 'Conductivity (µS/cm)'],
#       dtype='object')

# %% [markdown]
# Now, lets use some basic python functions such as info() and describe() to get some basic details about the datafframe....

# %%
water_quality_df.info()
water_quality_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample ID                500 non-null    int64
#  1   pH                       500 non-null    float64
#  2   Temperature (°C)         500 non-null    float64
#  3   Turbidity (NTU)          500 non-null    float64
#  4   Dissolved Oxygen (mg/L)  500 non-null    float64
#  5   Conductivity (µS/cm)     500 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 23.6 KB
#         Sample ID          pH  Temperature (°C)  Turbidity (NTU)  \
# count  500.000000  500.000000        500.000000       500.000000
# mean   250.500000    7.161140         22.054400         4.169400
# std    144.481833    0.107531          0.903123         0.397492
# min      1.000000    6.830000         20.300000         3.100000
# ...

# %% [markdown]
# ## Q1. Which samples are having pH level less than 7 i.e. acidic ?

# %%
acidic_water = water_quality_df.pH < 7
water_quality_df[acidic_water]
# Out:
#     Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 5           6  6.89              23.6              4.6
# 7           8  6.98              22.1              3.7
# 12         13  6.95              22.3              4.1
# 15         16  6.92              21.4              4.9
# 20         21  6.83              22.5              3.3
# 31         32  6.92              21.7              4.7
# 42         43  6.96              22.9              4.8
# 58         59  6.90              22.5              4.2
# 64         65  6.94              23.2              4.0
# 94         95  6.98              21.9              4.0
#
#     Dissolved Oxygen (mg/L)  Conductivity (µS/cm)
# 5                       7.2                   320
# 7                       6.9                   325
# 12                      6.4                   341
# 15                      6.8                   362
# 20                      6.1                   348
# 31                      6.3                   363
# ...

# %% [markdown]
# ## Q2. Which samples are having pH level more than 7 i.e. basic ?

# %%
basic_water = water_quality_df.pH > 7
water_quality_df[basic_water]
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 0            1  7.25              23.1              4.5
# 1            2  7.11              22.3              5.1
# 2            3  7.03              21.5              3.9
# 3            4  7.38              22.9              3.2
# 4            5  7.45              20.7              3.8
# ..         ...   ...               ...              ...
# 495        496  7.01              20.8              4.6
# 496        497  7.31              22.5              3.8
# 497        498  7.02              21.2              4.7
# 498        499  7.25              23.0              3.9
# 499        500  7.12              20.9              4.4
#
#      Dissolved Oxygen (mg/L)  Conductivity (µS/cm)
# 0                        7.8                   342
# 1                        6.2                   335
# 2                        8.3                   356
# 3                        9.5                   327
# ...

# %% [markdown]
# ## Q3. Can you show in a single dataframe all the samples which are Acidic (<7 pH), Basic(>7pH) and Neutral (=7) ?

# %%
water_quality_df.loc[water_quality_df['pH'] == 7, 'Neutral'] = 'True'
water_quality_df.loc[water_quality_df['pH'] < 7, 'Acidic'] = 'True'
water_quality_df.loc[water_quality_df['pH'] > 7, 'Basic'] = 'True'
water_quality_df
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 0            1  7.25              23.1              4.5
# 1            2  7.11              22.3              5.1
# 2            3  7.03              21.5              3.9
# 3            4  7.38              22.9              3.2
# 4            5  7.45              20.7              3.8
# ..         ...   ...               ...              ...
# 495        496  7.01              20.8              4.6
# 496        497  7.31              22.5              3.8
# 497        498  7.02              21.2              4.7
# 498        499  7.25              23.0              3.9
# 499        500  7.12              20.9              4.4
#
#      Dissolved Oxygen (mg/L)  Conductivity (µS/cm) Neutral Acidic Basic
# 0                        7.8                   342     NaN    NaN  True
# 1                        6.2                   335     NaN    NaN  True
# 2                        8.3                   356     NaN    NaN  True
# ...

# %% [markdown]
# ## Q4. Which samples are having highest temperature ?

# %%
water_quality_df.sort_values('Temperature (°C)', ascending=False).head(50)
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 5            6  6.89              23.6              4.6
# 13          14  7.06              23.5              3.7
# 224        225  7.11              23.5              3.6
# 159        160  7.12              23.5              4.6
# 289        290  7.12              23.5              4.5
# 40          41  7.28              23.5              3.7
# 193        194  7.08              23.5              3.8
# 67          68  7.26              23.5              4.6
# 22          23  7.16              23.4              4.5
# 169        170  7.33              23.4              4.5
# 114        115  7.26              23.4              3.3
# 129        130  7.10              23.4              4.8
# 204        205  7.14              23.4              4.7
# 269        270  7.33              23.4              4.6
# 57          58  7.01              23.4              3.6
# 90          91  7.27              23.4              4.2
# ...

# %% [markdown]
# As we can see, Sample ID 6 is having the highest temperature - 23.6 degree celsius
#
# ### With the help of this method, we can get all sort of information .......

# %%
water_quality_df.sort_values('Turbidity (NTU)', ascending = False).head(50)
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 1            2  7.11              22.3              5.1
# 27          28  7.09              23.3              5.0
# 34          35  7.03              22.6              4.9
# 15          16  6.92              21.4              4.9
# 71          72  7.03              23.0              4.8
# 351        352  7.29              22.8              4.8
# 59          60  7.29              21.9              4.8
# 109        110  7.33              22.4              4.8
# 321        322  7.29              22.8              4.8
# 381        382  7.29              22.8              4.8
# 129        130  7.10              23.4              4.8
# 42          43  6.96              22.9              4.8
# 411        412  7.29              22.8              4.8
# 91          92  7.04              21.5              4.8
# 441        442  7.29              22.8              4.8
# 145        146  7.09              21.9              4.8
# ...

# %% [markdown]
# Sample ID 2 is having the highest Turbidity

# %%
water_quality_df.sort_values('Conductivity (µS/cm)', ascending=False).head(50)
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 169        170  7.33              23.4              4.5
# 278        279  7.35              21.4              4.6
# 239        240  7.33              22.5              4.6
# 178        179  7.35              22.5              3.8
# 458        459  7.35              22.6              3.7
# 428        429  7.35              22.6              3.7
# 218        219  7.35              21.6              4.4
# 194        195  7.32              20.5              4.2
# 338        339  7.35              22.6              3.7
# 488        489  7.35              22.6              3.7
# 398        399  7.35              22.6              3.7
# 368        369  7.35              22.6              3.7
# 269        270  7.33              23.4              4.6
# 308        309  7.35              22.1              3.7
# 479        480  7.33              23.2              4.6
# 148        149  7.35              21.4              3.9
# ...

# %% [markdown]
# Sample ID 170 is having the highest Conductivity

# %%
water_quality_df.sort_values('Dissolved Oxygen (mg/L)', ascending=False).head(50)
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 169        170  7.33              23.4              4.5
# 239        240  7.33              22.5              4.6
# 479        480  7.33              23.2              4.6
# 269        270  7.33              23.4              4.6
# 389        390  7.33              23.2              4.6
# 178        179  7.35              22.5              3.8
# 359        360  7.33              23.2              4.6
# 194        195  7.32              20.5              4.2
# 299        300  7.33              23.1              4.5
# 419        420  7.33              23.2              4.6
# 449        450  7.33              23.2              4.6
# 148        149  7.35              21.4              3.9
# 329        330  7.33              23.2              4.6
# 139        140  7.33              21.2              4.4
# 248        249  7.35              21.5              4.7
# 338        339  7.35              22.6              3.7
# ...

# %% [markdown]
# Sample ID 170 is having the highest Dissolved Oxygen

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lets create a sub - dataframe which has the factors which acts as the pollutants (Turbidity, Conductivity) in decreasing order.....

# %%
polluted_water_df = water_quality_df.sort_values(['Turbidity (NTU)', 'Conductivity (µS/cm)' ], ascending=False).groupby('pH').head(50)
polluted_water_df
# Out:
#      Sample ID    pH  Temperature (°C)  Turbidity (NTU)  \
# 1            2  7.11              22.3              5.1
# 27          28  7.09              23.3              5.0
# 15          16  6.92              21.4              4.9
# 34          35  7.03              22.6              4.9
# 321        322  7.29              22.8              4.8
# ..         ...   ...               ...              ...
# 78          79  7.01              22.6              3.2
# 3            4  7.38              22.9              3.2
# 39          40  7.02              22.0              3.2
# 124        125  7.12              23.0              3.1
# 153        154  7.19              22.5              3.1
#
#      Dissolved Oxygen (mg/L)  Conductivity (µS/cm) Neutral Acidic Basic
# 1                        6.2                   335     NaN    NaN  True
# 27                       7.0                   324     NaN    NaN  True
# 15                       6.8                   362     NaN   True   NaN
# ...

# %% [markdown]
# Lets rename the column names for smooth operation in visualization....

# %%
polluted_water_df.rename(columns={'Sample ID': 'sample_id', 'Temperature (°C)':'Temp','Turbidity (NTU)' : 'Turbidity','Dissolved Oxygen (mg/L)':'Dissolved_oxygen','Conductivity (µS/cm)':'conductivity'   }, inplace=True)
polluted_water_df
# Out:
#      sample_id    pH  Temp  Turbidity  Dissolved_oxygen  conductivity Neutral  \
# 1            2  7.11  22.3        5.1               6.2           335     NaN
# 27          28  7.09  23.3        5.0               7.0           324     NaN
# 15          16  6.92  21.4        4.9               6.8           362     NaN
# 34          35  7.03  22.6        4.9               7.9           331     NaN
# 321        322  7.29  22.8        4.8               9.2           361     NaN
# ..         ...   ...   ...        ...               ...           ...     ...
# 78          79  7.01  22.6        3.2               8.2           339     NaN
# 3            4  7.38  22.9        3.2               9.5           327     NaN
# 39          40  7.02  22.0        3.2               8.8           318     NaN
# 124        125  7.12  23.0        3.1               9.4           356     NaN
# 153        154  7.19  22.5        3.1               9.6           351     NaN
#
#     Acidic Basic
# ...

# %% [markdown]
# Lets plot a scatter graph in which we can show all the samples with their different Turbidity Level . . . .

# %%
sns.set_style('whitegrid')
sns.relplot(x=polluted_water_df.sample_id, y = polluted_water_df.pH, hue = polluted_water_df.Turbidity);

# %% [markdown]
# Lets plot a scatter graph in which we can show all the samples with their different Conductivity Level . . . .

# %%
sns.set_style('whitegrid')
sns.relplot(x=polluted_water_df.sample_id, y = polluted_water_df.pH, hue = polluted_water_df.conductivity);

# %% [markdown]
# #### Lets take a sample data from the sub-dataframe for the simplicity purpose . . .

# %%
polluted_sample_df = polluted_water_df.sample(20)
polluted_sample_df
# Out:
#      sample_id    pH  Temp  Turbidity  Dissolved_oxygen  conductivity Neutral  \
# 258        259  7.25  22.8        3.8               9.5           359     NaN
# 497        498  7.02  21.2        4.7               7.5           334     NaN
# 228        229  7.25  21.8        4.6               7.5           335     NaN
# 108        109  7.01  20.8        3.6               8.4           330     NaN
# 188        189  7.25  20.7        4.6               8.7           346     NaN
# 163        164  7.18  23.0        4.1               8.9           347     NaN
# 380        381  7.16  21.7        4.1               8.3           344     NaN
# 239        240  7.33  22.5        4.6               9.9           370     NaN
# 164        165  7.14  20.5        3.6               8.0           333     NaN
# 41          42  7.14  20.9        4.3               8.1           330     NaN
# 103        104  7.05  20.9        3.7               8.1           339     NaN
# ...

# %% [markdown]
# Lets plot a graph showing both Turbidity Level and Sample ID for Axes values - Conductivity & Temperature.
#
# We can observe that among these sample data, Sample ID 309 is having the highest Conductivity and Temperature with Turbidity value 3.7

# %%
sns.set_style("whitegrid")
sns.relplot(x='Temp', y = 'conductivity', data=polluted_sample_df, hue=polluted_sample_df[['Turbidity', 'sample_id']].apply(tuple, axis=1));

# %% [markdown]
# Now we will plot a graph showing different conductivity level for every Sample ID.
# We can observe that as Sample ID is increasing, Conductivity is also increasing.

# %%
sns.scatterplot(x=polluted_water_df.sample_id, y=polluted_water_df.conductivity);
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# Lets plot a BarPlot showing variations for Dissolved Oxygen for every Sample ID. . .

# %%
sns.barplot(y=polluted_water_df.sample_id, x=polluted_water_df.Dissolved_oxygen)
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
import jovian

# %%
jovian.commit(project='python-matplotlib-data-visualizationver2.0')
# Out:
# [jovian] Creating a new project "siddharthpersonalblog/python-matplotlib-data-visualizationver2.0"
# [jovian] Committed successfully! https://jovian.com/siddharthpersonalblog/python-matplotlib-data-visualizationver2
# 'https://jovian.com/siddharthpersonalblog/python-matplotlib-data-visualizationver2'
